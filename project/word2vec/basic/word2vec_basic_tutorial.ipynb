# %% [markdown]
# ## word2vec_basic tutorial

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %% [markdown]
# ### Step 1: Download the data.

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
words = words[:1000]

# %% [markdown]
# ### Step 2: Build the dictionary and replace rare words with UNK token.

# %%
# vocabulary_size = 50000
vocabulary_size = 100
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 395], ('the', 58), ('of', 41), ('in', 30), ('and', 27)]
# Sample data [12, 0, 6, 9, 29, 2, 0, 41, 73, 0] ['anarchism', 'UNK', 'as', 'a', 'term', 'of', 'UNK', 'first', 'used', 'UNK']

# %% [markdown]
# ### Step 3: Function to generate a training batch for the skip-gram model.

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 0 UNK -> 12 anarchism
# 0 UNK -> 6 as
# 6 as -> 0 UNK
# 6 as -> 9 a
# 9 a -> 6 as
# 9 a -> 29 term
# 29 term -> 2 of
# 29 term -> 9 a

# %% [markdown]
# ### Step 4: Build and train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %% [markdown]
# ### Step 5: Begin training.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  62.6092376709
# Nearest to used: property, is, published, labor, have, about, authoritarian, the,
# Nearest to and: some, rights, stirner, that, movement, political, their, commonly,
# Nearest to at: so, state, be, positive, the, from, rights, use,
# Nearest to anarchist: positive, published, property, the, russell, be, stirner, its,
# Nearest to use: working, most, stirner, philosophy, resources, interpretations, movement, self,
# Nearest to free: eight, their, modern, self, ideas, proudhon, anarchists, social,
# Nearest to anarchy: positive, anarchism, word, godwin, one, about, work, my,
# Nearest to the: stirner, his, access, anarchist, russell, eight, state, at,
# Nearest to my: where, others, institutions, in, founder, with, anarchy, a,
# Nearest to called: society, it, are, would, by, s, access, including,
# Nearest to institutions: there, my, was, also, where, others, russell, labor,
# Nearest to positive: no, anarchist, working, state, published, from, anarchy, interpretations,
# Nearest to movement: four, are, published, use, and, stirner, to, where,
# Nearest to in: authoritarian, this, anarchists, that, or, four, my, where,
# Nearest to political: as, they, and, one, an, russell, free, or,
# Nearest to godwin: rights, authoritarian, history, have, he, kropotkin, in, anarchy,
# Average loss at step  2000 :  3.51135083854
# Average loss at step  4000 :  3.3741339277
# Average loss at step  6000 :  3.3670641377
# Average loss at step  8000 :  3.36273428607
# Average loss at step  10000 :  3.35875249302
# Nearest to used: property, UNK, is, published, the, most, rights, have,
# Nearest to and: movement, state, some, rights, stirner, to, UNK, four,
# Nearest to at: so, be, from, positive, which, commonly, where, my,
# Nearest to anarchist: positive, called, published, stirner, its, property, there, the,
# Nearest to use: UNK, working, resources, state, most, the, stirner, movement,
# Nearest to free: eight, self, their, UNK, modern, anarchists, were, political,
# Nearest to anarchy: anarchism, one, word, state, french, my, about, revolution,
# Nearest to the: russell, others, his, stirner, anarchism, some, UNK, state,
# Nearest to my: where, others, UNK, a, anarchism, was, with, at,
# Nearest to called: anarchist, are, would, s, society, it, by, commonly,
# Nearest to institutions: also, there, my, was, an, russell, movement, labor,
# Nearest to positive: anarchist, working, no, at, state, from, have, involved,
# Nearest to movement: four, and, are, stirner, UNK, to, where, an,
# Nearest to in: four, all, authoritarian, or, this, labor, anarchists, from,
# Nearest to political: they, free, as, or, and, about, UNK, russell,
# Nearest to godwin: have, rights, authoritarian, kropotkin, UNK, history, all, anarchists,
# Average loss at step  12000 :  3.35671348381
# Average loss at step  14000 :  3.35316430378
# Average loss at step  16000 :  3.35054098821
# Average loss at step  18000 :  3.34907986486
# Average loss at step  20000 :  3.34690619802
# Nearest to used: property, UNK, most, rights, is, have, work, the,
# Nearest to and: state, movement, of, to, four, he, are, stirner,
# Nearest to at: from, so, be, positive, which, commonly, where, my,
# Nearest to anarchist: positive, called, stirner, institutions, there, involved, its, be,
# Nearest to use: UNK, state, working, resources, the, access, movement, stirner,
# Nearest to free: self, eight, modern, anarchists, their, be, UNK, the,
# Nearest to anarchy: anarchism, one, word, state, french, revolution, my, about,
# Nearest to the: others, russell, anarchism, some, UNK, state, stirner, his,
# Nearest to my: where, others, a, anarchism, UNK, was, which, at,
# Nearest to called: anarchist, are, would, s, commonly, it, society, they,
# Nearest to institutions: also, there, the, an, at, anarchist, movement, of,
# Nearest to positive: anarchist, working, no, at, have, involved, how, state,
# Nearest to movement: four, and, are, stirner, to, an, where, UNK,
# Nearest to in: all, four, of, state, labor, including, positive, from,
# Nearest to political: they, free, or, and, i, institutions, called, to,
# Nearest to godwin: have, authoritarian, rights, kropotkin, UNK, self, anarchists, all,
# Average loss at step  22000 :  3.34643557119
# Average loss at step  24000 :  3.34421319616
# Average loss at step  26000 :  3.3433432337
# Average loss at step  28000 :  3.34299806428
# Average loss at step  30000 :  3.34258790088
# Nearest to used: property, most, rights, have, work, is, social, published,
# Nearest to and: state, movement, of, to, four, by, are, he,
# Nearest to at: from, be, so, positive, which, commonly, institutions, my,
# Nearest to anarchist: called, positive, involved, institutions, there, a, stirner, its,
# Nearest to use: state, the, resources, UNK, working, access, term, movement,
# Nearest to free: self, eight, modern, be, anarchists, means, the, at,
# Nearest to anarchy: anarchism, one, word, state, revolution, french, society, my,
# Nearest to the: some, others, anarchism, russell, state, their, was, stirner,
# Nearest to my: where, anarchism, a, others, which, was, at, its,
# Nearest to called: anarchist, s, would, it, are, commonly, or, society,
# Nearest to institutions: also, an, the, at, anarchist, movement, there, of,
# Nearest to positive: anarchist, working, no, at, have, how, involved, in,
# Nearest to movement: four, and, an, are, to, stirner, where, society,
# Nearest to in: all, four, of, state, are, including, positive, to,
# Nearest to political: they, or, free, be, institutions, called, and, i,
# Nearest to godwin: have, authoritarian, rights, kropotkin, proudhon, self, they, anarchists,
# Average loss at step  32000 :  3.34130820107
# Average loss at step  34000 :  3.3401923089
# Average loss at step  36000 :  3.33868508399
# Average loss at step  38000 :  3.3383966682
# Average loss at step  40000 :  3.33888259697
# Nearest to used: most, rights, property, have, work, social, is, which,
# Nearest to and: state, of, movement, by, to, are, four, in,
# Nearest to at: from, be, so, positive, which, commonly, institutions, my,
# Nearest to anarchist: called, positive, involved, a, institutions, it, there, social,
# Nearest to use: state, resources, the, UNK, term, access, working, founder,
# Nearest to free: self, eight, be, means, modern, property, anarchists, at,
# Nearest to anarchy: anarchism, one, word, revolution, state, society, french, my,
# Nearest to the: some, was, others, state, working, anarchism, russell, property,
# Nearest to my: where, anarchism, which, a, was, others, property, at,
# Nearest to called: anarchist, it, or, would, s, commonly, they, anarchism,
# Nearest to institutions: also, an, at, anarchist, movement, the, political, russell,
# Nearest to positive: working, anarchist, at, no, have, how, involved, in,
# Nearest to movement: four, an, to, and, are, stirner, where, society,
# Nearest to in: all, state, of, four, are, including, and, to,
# Nearest to political: they, or, free, be, called, institutions, i, to,
# Nearest to godwin: have, authoritarian, proudhon, kropotkin, self, rights, they, property,
# Average loss at step  42000 :  3.33822085702
# Average loss at step  44000 :  3.33759030855
# Average loss at step  46000 :  3.33721121335
# Average loss at step  48000 :  3.33596224129
# Average loss at step  50000 :  3.33549599183
# Nearest to used: most, rights, have, social, property, work, which, kropotkin,
# Nearest to and: state, by, of, to, movement, are, four, all,
# Nearest to at: from, be, positive, so, which, work, kropotkin, commonly,
# Nearest to anarchist: called, positive, involved, it, social, a, institutions, there,
# Nearest to use: state, resources, term, the, access, founder, working, kropotkin,
# Nearest to free: self, eight, be, means, property, at, modern, his,
# Nearest to anarchy: one, anarchism, revolution, society, word, state, to, my,
# Nearest to the: some, working, was, state, anarchism, use, property, others,
# Nearest to my: where, anarchism, which, property, was, a, at, others,
# Nearest to called: anarchist, or, it, anarchism, s, commonly, they, would,
# Nearest to institutions: also, an, at, anarchist, movement, political, the, russell,
# Nearest to positive: working, at, anarchist, have, no, how, be, involved,
# Nearest to movement: four, an, are, to, and, stirner, where, with,
# Nearest to in: all, state, of, four, are, and, including, positive,
# Nearest to political: they, or, be, free, called, institutions, i, to,
# Nearest to godwin: have, proudhon, authoritarian, self, kropotkin, they, rights, property,
# Average loss at step  52000 :  3.33559552097
# Average loss at step  54000 :  3.33557745838
# Average loss at step  56000 :  3.33482509196
# Average loss at step  58000 :  3.33502157974
# Average loss at step  60000 :  3.33451083601
# Nearest to used: most, have, rights, social, work, which, kropotkin, one,
# Nearest to and: state, by, of, to, are, movement, all, in,
# Nearest to at: from, be, positive, so, which, kropotkin, work, free,
# Nearest to anarchist: called, involved, social, it, positive, a, were, others,
# Nearest to use: the, term, state, resources, access, founder, kropotkin, revolution,
# Nearest to free: self, be, eight, at, called, means, property, in,
# Nearest to anarchy: one, anarchism, revolution, society, state, word, to, my,
# Nearest to the: some, working, use, was, this, state, one, term,
# Nearest to my: which, anarchism, where, property, was, at, others, its,
# Nearest to called: anarchist, or, anarchism, it, free, they, commonly, s,
# Nearest to institutions: also, an, at, movement, anarchist, political, russell, others,
# Nearest to positive: working, at, have, no, be, how, anarchist, involved,
# Nearest to movement: an, four, are, stirner, to, and, where, with,
# Nearest to in: state, all, of, and, four, are, free, including,
# Nearest to political: be, they, or, free, called, institutions, i, at,
# Nearest to godwin: have, proudhon, self, authoritarian, they, kropotkin, property, so,
# Average loss at step  62000 :  3.33416375458
# Average loss at step  64000 :  3.3337944783
# Average loss at step  66000 :  3.33351842904
# Average loss at step  68000 :  3.33283933175
# Average loss at step  70000 :  3.33284898674
# Nearest to used: most, have, rights, social, work, kropotkin, which, one,
# Nearest to and: state, by, are, to, of, movement, all, in,
# Nearest to at: from, be, positive, so, which, kropotkin, free, work,
# Nearest to anarchist: called, involved, social, it, were, positive, revolution, a,
# Nearest to use: term, the, resources, state, kropotkin, founder, access, revolution,
# Nearest to free: self, be, at, called, in, means, political, revolution,
# Nearest to anarchy: one, anarchism, revolution, society, state, word, to, anarchists,
# Nearest to the: working, use, some, one, was, term, this, anarchism,
# Nearest to my: which, where, anarchism, property, was, at, its, others,
# Nearest to called: anarchist, or, free, anarchism, they, is, it, commonly,
# Nearest to institutions: an, also, at, movement, anarchist, political, russell, others,
# Nearest to positive: at, working, be, have, no, how, anarchist, involved,
# Nearest to movement: an, four, are, stirner, and, to, with, where,
# Nearest to in: state, all, free, at, of, four, means, and,
# Nearest to political: be, or, free, they, called, institutions, i, at,
# Nearest to godwin: have, proudhon, self, they, kropotkin, authoritarian, so, are,
# Average loss at step  72000 :  3.33281879163
# Average loss at step  74000 :  3.33224073768
# Average loss at step  76000 :  3.33117123723
# Average loss at step  78000 :  3.33108643639
# Average loss at step  80000 :  3.3304983269
# Nearest to used: most, have, rights, social, one, kropotkin, work, which,
# Nearest to and: state, by, are, to, of, movement, all, in,
# Nearest to at: from, be, positive, so, which, free, kropotkin, for,
# Nearest to anarchist: called, social, involved, it, were, law, revolution, others,
# Nearest to use: term, the, resources, kropotkin, state, founder, access, revolution,
# Nearest to free: self, called, be, at, in, means, revolution, political,
# Nearest to anarchy: one, anarchism, state, revolution, society, word, anarchists, to,
# Nearest to the: use, working, one, some, most, was, term, this,
# Nearest to my: which, where, at, anarchism, was, property, its, with,
# Nearest to called: anarchist, or, free, anarchism, is, they, it, about,
# Nearest to institutions: an, also, at, movement, political, anarchist, have, russell,
# Nearest to positive: at, working, be, have, no, how, free, involved,
# Nearest to movement: an, four, are, stirner, and, with, where, or,
# Nearest to in: state, free, all, means, at, as, and, four,
# Nearest to political: be, free, or, they, called, are, at, institutions,
# Nearest to godwin: have, proudhon, self, they, kropotkin, so, are, authoritarian,
# Average loss at step  82000 :  3.33068224537
# Average loss at step  84000 :  3.33015750253
# Average loss at step  86000 :  3.33039586151
# Average loss at step  88000 :  3.32988273215
# Average loss at step  90000 :  3.33002025425
# Nearest to used: most, have, rights, social, one, kropotkin, work, is,
# Nearest to and: state, by, to, are, of, movement, all, he,
# Nearest to at: from, positive, be, free, so, kropotkin, which, for,
# Nearest to anarchist: called, were, it, social, involved, law, revolution, free,
# Nearest to use: term, kropotkin, resources, founder, revolution, the, state, individuals,
# Nearest to free: self, called, at, be, in, were, revolution, it,
# Nearest to anarchy: one, anarchism, society, state, revolution, anarchists, word, french,
# Nearest to the: one, use, working, revolution, some, was, most, of,
# Nearest to my: which, at, where, was, anarchism, property, its, with,
# Nearest to called: anarchist, free, or, they, about, is, anarchism, s,
# Nearest to institutions: an, also, at, movement, political, have, anarchist, s,
# Nearest to positive: at, working, be, have, no, how, free, or,
# Nearest to movement: an, four, are, stirner, with, or, and, where,
# Nearest to in: state, free, at, means, as, all, that, of,
# Nearest to political: be, free, or, they, called, are, at, institutions,
# Nearest to godwin: have, proudhon, self, they, kropotkin, are, so, there,
# Average loss at step  92000 :  3.32975288522
# Average loss at step  94000 :  3.32953481948
# Average loss at step  96000 :  3.33006042278
# Average loss at step  98000 :  3.3300746609
# Average loss at step  100000 :  3.33010996485
# Nearest to used: most, have, rights, kropotkin, social, one, is, work,
# Nearest to and: to, by, state, all, are, of, movement, he,
# Nearest to at: from, be, free, positive, so, kropotkin, for, work,
# Nearest to anarchist: called, were, it, social, involved, law, free, revolution,
# Nearest to use: term, kropotkin, revolution, founder, resources, individuals, state, the,
# Nearest to free: self, called, at, in, be, were, it, was,
# Nearest to anarchy: one, anarchism, society, state, revolution, anarchists, his, word,
# Nearest to the: working, most, use, one, revolution, some, of, was,
# Nearest to my: which, at, where, was, anarchism, its, with, property,
# Nearest to called: anarchist, free, or, about, they, s, anarchism, have,
# Nearest to institutions: an, also, at, movement, political, have, anarchist, s,
# Nearest to positive: at, be, working, how, no, have, free, or,
# Nearest to movement: an, four, are, stirner, or, with, where, all,
# Nearest to in: free, state, at, means, that, positive, all, including,
# Nearest to political: be, free, or, called, they, are, at, institutions,
# Nearest to godwin: proudhon, have, they, self, so, kropotkin, there, are,

# %% [markdown]
# ### Step 6: Visualize the embeddings.

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 100
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")

# %%
final_embeddings[0]
# Out:
# array([-0.28100106, -0.02178469, -0.00772871, -0.07230854, -0.09403515,
#        -0.10868663, -0.13462064, -0.11825618,  0.02475498,  0.15696728,
#         0.13765572,  0.07022373, -0.19128451,  0.08296666,  0.05802054,
#         0.05380245, -0.00845535, -0.02074416,  0.01828231, -0.08659802,
#        -0.13272153, -0.02187963,  0.01768884, -0.02786022, -0.05250518,
#         0.05901526, -0.030745  ,  0.00662905,  0.03902665, -0.02326796,
#         0.07933673,  0.04198802,  0.09966143, -0.07301378, -0.01222722,
#        -0.02779971,  0.03572263,  0.10417381,  0.03784221,  0.08303193,
#         0.04439615, -0.10269686,  0.03039251, -0.11014935, -0.13060102,
#         0.16301826,  0.14987044, -0.12272222,  0.1266105 , -0.03427912,
#        -0.01730915, -0.04074357,  0.02476451, -0.13315471, -0.08276926,
#        -0.13077059, -0.00570791, -0.04383882, -0.07696181,  0.07634395,
#         0.02161441,  0.02956789, -0.03023163,  0.10157494,  0.07468069,
#         0.02548671, -0.1077886 ,  0.08746192, -0.06834932,  0.26473698,
#        -0.0809139 ,  0.05813155, -0.07010332, -0.04490288,  0.12700263,
#        -0.0735788 ,  0.10986675, -0.02795863, -0.1095539 , -0.03223438,
#        -0.01007681,  0.09746079, -0.0333692 , -0.08978704,  0.08500211,
#        -0.05743925, -0.02654886, -0.08524013, -0.04167772, -0.1337664 ,
#         0.03148318,  0.16019887,  0.07703374,  0.07537182,  0.04041312,
#         0.00054663,  0.04804374,  0.0414359 , -0.04202726,  0.08632722,
#         0.02710203, -0.02357725,  0.04858371,  0.01348006, -0.07886761,
#        -0.00089388,  0.01272932, -0.06952274, -0.09861647,  0.07391118,
#         0.09389985,  0.01965008, -0.0653532 , -0.06840508, -0.02704851,
#         0.15432474, -0.14858016, -0.22381116, -0.06116773,  0.07372296,
#         0.02342793, -0.14276262,  0.02690074,  0.12479992, -0.06162175,
#         0.0226935 , -0.00712674,  0.13115862], dtype=float32)

# %%
final_embeddings.shape
# Out:
# (100, 128)

# %%
ls
# Out:
# data/     get_data.ipynb  text8.zip       tsne.png
# data_cp/  get_data.py     topic_list.txt  word2vec_basic_tutorial.ipynb

# %%
from IPython.display import Image
i = Image(filename='tsne.png')
from IPython.display import display
display(i)
